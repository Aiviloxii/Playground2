# %% [markdown]
# ## LearningPandas: Pandas is panel data created by Wes mcKinney in 2008 from Numpy libraries

# %%
import pandas as pd

# %% [markdown]
# ## Panda Series

# %%
a = pd.Series([1, 2, 3, 4 ,5])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a_explicit = pd.Series([1.4, 2, 3.1, 5, 4.8], index=['a', 'b', 'c', 'd', 'e'])

# %%
a_explicit['c']
# Out:
# 3.1

# %%
a_explicit
# Out:
# a    1.4
# b    2.0
# c    3.1
# d    5.0
# e    4.8
# dtype: float64

# %% [markdown]
# ## Panda DataFrames

# %%
heights = {'John': 1.70, 'Mary': 1.59, 'Hassan': 1.89, 'Aisha': 1.67}

# %%
weights = {'John':56, 'Mary': 49, 'Hassan': 65, 'Aisha': 58}

# %%
data = pd.DataFrame({'heights':heights, 'weights': weights})

# %%
data
# Out:
#         heights  weights
# John       1.70       56
# Mary       1.59       49
# Hassan     1.89       65
# Aisha      1.67       58

# %%
data.index
# Out:
# Index(['John', 'Mary', 'Hassan', 'Aisha'], dtype='object')

# %%
data.reset_index()
# Out:
#     index  heights  weights
# 0    John     1.70       56
# 1    Mary     1.59       49
# 2  Hassan     1.89       65
# 3   Aisha     1.67       58

# %%
data
# Out:
#         heights  weights
# John       1.70       56
# Mary       1.59       49
# Hassan     1.89       65
# Aisha      1.67       58

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#     index  heights  weights
# 0    John     1.70       56
# 1    Mary     1.59       49
# 2  Hassan     1.89       65
# 3   Aisha     1.67       58

# %%
data.rename(columns={'index':'name'}, inplace=True)

# %%
data
# Out:
#      name  heights  weights
# 0    John     1.70       56
# 1    Mary     1.59       49
# 2  Hassan     1.89       65
# 3   Aisha     1.67       58

# %%
data['name']
# Out:
# 0      John
# 1      Mary
# 2    Hassan
# 3     Aisha
# Name: name, dtype: object

# %%
data['weights']
# Out:
# 0    56
# 1    49
# 2    65
# 3    58
# Name: weights, dtype: int64

# %% [markdown]
# ## using loc

# %%
data
# Out:
#      name  heights  weights
# 0    John     1.70       56
# 1    Mary     1.59       49
# 2  Hassan     1.89       65
# 3   Aisha     1.67       58

# %%
data.set_index('name', inplace=True)

# %%
data
# Out:
#         heights  weights
# name
# John       1.70       56
# Mary       1.59       49
# Hassan     1.89       65
# Aisha      1.67       58

# %%
data.loc['John', 'heights']
# Out:
# 1.7

# %%
data.loc['Hassan', 'weights']
# Out:
# 65

# %%
data.loc[:'Hassan', :]
# Out:
#         heights  weights
# name
# John       1.70       56
# Mary       1.59       49
# Hassan     1.89       65

# %%
data.loc['John': 'Hassan', 'weights']
# Out:
# name
# John      56
# Mary      49
# Hassan    65
# Name: weights, dtype: int64

# %%
data.loc['Mary': 'Aisha', 'heights']
# Out:
# name
# Mary      1.59
# Hassan    1.89
# Aisha     1.67
# Name: heights, dtype: float64

# %% [markdown]
# ## Using iloc

# %%
data
# Out:
#         heights  weights
# name
# John       1.70       56
# Mary       1.59       49
# Hassan     1.89       65
# Aisha      1.67       58

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#      name  heights  weights
# 0    John     1.70       56
# 1    Mary     1.59       49
# 2  Hassan     1.89       65
# 3   Aisha     1.67       58

# %%
data.iloc[0,1]
# Out:
# 1.7

# %%
data.iloc[0,0]
# Out:
# 'John'

# %%
data.iloc[2,2]
# Out:
# 65

# %%
data.iloc[:2, :]
# Out:
#    name  heights  weights
# 0  John     1.70       56
# 1  Mary     1.59       49

# %%
data.iloc[0:2]
# Out:
#    name  heights  weights
# 0  John     1.70       56
# 1  Mary     1.59       49

# %%
data.iloc[:1, 1]
# Out:
# 0    1.7
# Name: heights, dtype: float64

# %% [markdown]
# ## Adding new columns

# %%
data
# Out:
#      name  heights  weights
# 0    John     1.70       56
# 1    Mary     1.59       49
# 2  Hassan     1.89       65
# 3   Aisha     1.67       58

# %%
data['bmi']= data['weights']/ (data['heights']**2)

# %%
data
# Out:
#      name  heights  weights        bmi
# 0    John     1.70       56  19.377163
# 1    Mary     1.59       49  19.382145
# 2  Hassan     1.89       65  18.196579
# 3   Aisha     1.67       58  20.796730

# %% [markdown]
# ## Importing Datasets

# %%
population_data = pd.read_csv("../Datasets/world_population.csv")

# %%
population_data
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
world_bank = pd.read_excel("../Datasets/WorldBank.xlsx", sheet_name=0)

# %%
world_bank
# Out:
#       Country Name Country Code              Region IncomeGroup  Year  \
# 0      Afghanistan          AFG          South Asia  Low income  2018
# 1      Afghanistan          AFG          South Asia  Low income  2017
# 2      Afghanistan          AFG          South Asia  Low income  2016
# 3      Afghanistan          AFG          South Asia  Low income  2015
# 4      Afghanistan          AFG          South Asia  Low income  2014
# ...            ...          ...                 ...         ...   ...
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth rate, crude (per 1,000 people)  \
# 0                                       NaN
# ...

# %%
population_data.shape #shows the number of rows and columns
# Out:
# (234, 17)

# %%
population_data.head() #displays first five rows
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
population_data.head(20) #displays first 20 rows
# Out:
#     Rank CCA3    Country/Territory           Capital      Continent  \
# 0     36  AFG          Afghanistan             Kabul           Asia
# 1    138  ALB              Albania            Tirana         Europe
# 2     34  DZA              Algeria           Algiers         Africa
# 3    213  ASM       American Samoa         Pago Pago        Oceania
# 4    203  AND              Andorra  Andorra la Vella         Europe
# 5     42  AGO               Angola            Luanda         Africa
# 6    224  AIA             Anguilla        The Valley  North America
# 7    201  ATG  Antigua and Barbuda      Saint John’s  North America
# 8     33  ARG            Argentina      Buenos Aires  South America
# 9    140  ARM              Armenia           Yerevan           Asia
# 10   198  ABW                Aruba        Oranjestad  North America
# 11    55  AUS            Australia          Canberra        Oceania
# 12    99  AUT              Austria            Vienna         Europe
# ...

# %%
population_data.tail() #displays the last 5 rows
# Out:
#      Rank CCA3  Country/Territory   Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna  Mata-Utu   Oceania            11572
# 230   172  ESH     Western Sahara  El Aaiún    Africa           575986
# 231    46  YEM              Yemen     Sanaa      Asia         33696614
# 232    63  ZMB             Zambia    Lusaka    Africa         20017675
# 233    74  ZWE           Zimbabwe    Harare    Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229            11655            12182            13142            14723
# 230           556048           491824           413296           270375
# 231         32284046         28516545         24743946         18628700
# 232         18927715         16248230         13792086          9891136
# 233         15669666         14154937         12839771         11834676
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
population_data.sample() #selects a random row
# Out:
#      Rank CCA3 Country/Territory    Capital Continent  2022 Population  \
# 187   113  SGP         Singapore  Singapore      Asia          5975689
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 187          5909869          5650018          5163590          4053602
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 187          3022209          2400729          2061831         710
#
#      Density (per km²)  Growth Rate  World Population Percentage
# 187          8416.4634       1.0058                         0.07

# %%
population_data.sample(10) # selects 10 rows randomly
# Out:
#      Rank CCA3             Country/Territory           Capital      Continent  \
# 23    165  BTN                        Bhutan           Thimphu           Asia
# 100    52  CIV                   Ivory Coast      Yamoussoukro         Africa
# 43    163  COM                       Comoros            Moroni         Africa
# 153   210  NFK      Northern Mariana Islands            Saipan        Oceania
# 33     73  KHM                      Cambodia        Phnom Penh           Asia
# 47     85  CUB                          Cuba            Havana  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
# 192    70  SOM                       Somalia         Mogadishu         Africa
# 145   185  NCL                 New Caledonia            Nouméa        Oceania
# 214   111  TKM                  Turkmenistan          Ashgabat           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
population_data.index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %%
population_data.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
population_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
population_data.values
# Out:
# array([[36, 'AFG', 'Afghanistan', ..., 63.0587, 1.0257, 0.52],
#        [138, 'ALB', 'Albania', ..., 98.8702, 0.9957, 0.04],
#        [34, 'DZA', 'Algeria', ..., 18.8531, 1.0164, 0.56],
#        ...,
#        [46, 'YEM', 'Yemen', ..., 63.8232, 1.0217, 0.42],
#        [63, 'ZMB', 'Zambia', ..., 26.5976, 1.028, 0.25],
#        [74, 'ZWE', 'Zimbabwe', ..., 41.7665, 1.0204, 0.2]], dtype=object)

# %%
population_data.isna().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
population_data.duplicated().sum()
# Out:
# 0

# %%
population_data.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
population_data.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
data = population_data[["Country/Territory", "Capital", "Continent", "2022 Population"]]

# %%
population_data.sort_values(by="Rank", inplace=True)

# %%
population_data.head()
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
population_data.iloc[:10]
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
# 149     6  NGA           Nigeria             Abuja         Africa
# 27      7  BRA            Brazil          Brasilia  South America
# 16      8  BGD        Bangladesh             Dhaka           Asia
# 171     9  RUS            Russia            Moscow         Europe
# 131    10  MEX            Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# ...

# %%
populus_country = population_data[["Rank", "Country/Territory", "2022 Population"]] [:10]
populus_country
# Out:
#      Rank Country/Territory  2022 Population
# 41      1             China       1425887337
# 92      2             India       1417173173
# 221     3     United States        338289857
# 93      4         Indonesia        275501339
# 156     5          Pakistan        235824862
# 149     6           Nigeria        218541212
# 27      7            Brazil        215313498
# 16      8        Bangladesh        171186372
# 171     9            Russia        144713314
# 131    10            Mexico        127504125

# %%
population_data.head()
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
population_data["2020 density"] = population_data["2020 Population"] / population_data["Area (km²)"]

# %%
population_data.head()
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
population_data["Continent"].value_counts()
# Out:
# Continent
# Africa           57
# Asia             50
# Europe           50
# North America    40
# Oceania          23
# South America    14
# Name: count, dtype: int64

# %%
continent_list = list(population_data["Continent"].unique()) #gets distincts values

# %%
continent_list
# Out:
# ['Asia', 'North America', 'Africa', 'South America', 'Europe', 'Oceania']

# %%
population_data.head()
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
over_100million = population_data[population_data["2022 Population"] > 100000000]

# %%
over_100million
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
# 149     6  NGA           Nigeria             Abuja         Africa
# 27      7  BRA            Brazil          Brasilia  South America
# 16      8  BGD        Bangladesh             Dhaka           Asia
# 171     9  RUS            Russia            Moscow         Europe
# 131    10  MEX            Mexico       Mexico City  North America
# 102    11  JPN             Japan             Tokyo           Asia
# 63     12  ETH          Ethiopia       Addis Ababa         Africa
# 163    13  PHL       Philippines            Manila           Asia
# ...

# %%
over_100million.shape
# Out:
# (14, 18)

# %%
over_100million_africa = population_data[(population_data["2022 Population"] > 100000000) & (population_data["Continent"] == "Africa")]

# %%
over_100million_africa
# Out:
#      Rank CCA3 Country/Territory      Capital Continent  2022 Population  \
# 149     6  NGA           Nigeria        Abuja    Africa        218541212
# 63     12  ETH          Ethiopia  Addis Ababa    Africa        123379924
# 57     14  EGY             Egypt        Cairo    Africa        110990103
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 149        208327405        183995785        160952853        122851984
# 63         117190911        102471895         89237791         67031867
# 57         107465134         97723799         87252413         71371371
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 149         95214257         72951439         55569264      923768
# 63          47878073         34945469         28308246     1104300
# 57          57214630         43748556         34781986     1002450
#
#      Density (per km²)  Growth Rate  World Population Percentage  2020 density
# ...

# %%
population_data.drop(columns=["2020 density"], inplace=True)

# %%
population_data.head()
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...
